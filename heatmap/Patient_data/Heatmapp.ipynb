# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("NormalizedValues.csv")

# %%
df= df.set_index('Unnamed: 0')

# %%
df.head()
# Out:
#             GSM746726.CEL.gz  GSM746727.CEL.gz  GSM746728.CEL.gz  \
# Unnamed: 0
# 1007_s_at           7.201025          6.946023          6.722365
# 1053_at             6.329305          6.525640          6.323421
# 117_at              4.943542          4.075428          5.173628
# 121_at              5.964546          5.959280          5.956050
# 1255_g_at           2.988337          2.858992          3.059207
#
#             GSM746729.CEL.gz  GSM746730.CEL.gz  GSM746731.CEL.gz  \
# Unnamed: 0
# 1007_s_at           6.478128          7.657810          7.458468
# 1053_at             5.788303          7.064163          6.475584
# 117_at              5.161637          5.879726          5.207273
# 121_at              5.891120          6.207989          6.155414
# 1255_g_at           2.947488          2.964566          2.832753
#
#             GSM746732.CEL.gz  GSM746733.CEL.gz  GSM746734.CEL.gz  \
# Unnamed: 0
# 1007_s_at           7.128305          6.893231          7.417922
# 1053_at             6.394097          6.708787          6.457130
# 117_at              4.860286          4.589202          5.545966
# 121_at              5.936915          5.647587          6.175860
# 1255_g_at           2.931560          2.887400          2.843799
#
#             GSM746735.CEL.gz  ...  GSM746742.CEL.gz  GSM746743.CEL.gz  \
# Unnamed: 0                    ...
# 1007_s_at           6.931448  ...          6.946717          7.001736
# 1053_at             6.407173  ...          6.427475          6.417270
# 117_at              5.397000  ...          4.879310          6.204755
# 121_at              5.905099  ...          5.931885          5.819153
# 1255_g_at           2.996664  ...          2.957946          3.081672
#
#             GSM746744.CEL.gz  GSM746745.CEL.gz  GSM746746.CEL.gz  \
# Unnamed: 0
# 1007_s_at           7.674026          7.207440          7.237125
# 1053_at             6.583484          6.304779          6.631808
# 117_at              5.462083          5.162356          5.182004
# 121_at              5.634927          6.063122          5.618122
# 1255_g_at           2.945571          2.987873          2.740603
#
#             GSM746747.CEL.gz  GSM746748.CEL.gz  GSM746750.CEL.gz  \
# Unnamed: 0
# 1007_s_at           6.819794          7.261244          6.934861
# 1053_at             6.496153          6.584563          6.376337
# 117_at              5.214218          4.657415          5.199447
# 121_at              5.627996          6.050202          5.744575
# 1255_g_at           2.750115          2.651826          2.915656
#
#             GSM746751.CEL.gz  GSM746752.CEL.gz
# Unnamed: 0
# 1007_s_at           7.003596          7.275133
# 1053_at             6.355599          6.419475
# 117_at              5.796467          4.687595
# 121_at              6.366826          5.910187
# 1255_g_at           2.985502          2.975618
#
# [5 rows x 26 columns]

# %%
len(df.columns)
# Out:
# 26

# %%
l1=[]
for i in range(1,18):
    l1.append("Patient"+str(i))
for i in range(1,11):
    if i != 7:
        l1.append("Control"+str(i))
df.columns = l1

# %%
df.shape
# Out:
# (54675, 26)

# %%
df= np.log2(df)

# %%
df.head()
# Out:
#             Patient1  Patient2  Patient3  Patient4  Patient5  Patient6  \
# Unnamed: 0
# 1007_s_at   2.848202  2.796187  2.748969  2.695577  2.936932  2.898879
# 1053_at     2.662047  2.706119  2.660705  2.533140  2.820519  2.695010
# 117_at      2.305545  2.026952  2.371176  2.367829  2.555749  2.380528
# 121_at      2.576412  2.575138  2.574356  2.558542  2.634126  2.621856
# 1255_g_at   1.579343  1.515506  1.613158  1.559486  1.567821  1.502205
#
#             Patient7  Patient8  Patient9  Patient10  ...  Patient17  Control1  \
# Unnamed: 0                                           ...
# 1007_s_at   2.833559  2.785180  2.891015   2.793157  ...   2.796331  2.807713
# 1053_at     2.676741  2.746052  2.690893   2.679688  ...   2.684252  2.681960
# 117_at      2.281041  2.198243  2.471439   2.432158  ...   2.286677  2.633374
# 121_at      2.569713  2.497635  2.626640   2.561961  ...   2.568491  2.540809
# 1255_g_at   1.551669  1.529771  1.507819   1.583358  ...   1.564596  1.623713
#
#             Control2  Control3  Control4  Control5  Control6  Control8  \
# Unnamed: 0
# 1007_s_at   2.939984  2.849487  2.855417  2.769728  2.860217  2.793867
# 1053_at     2.718851  2.656446  2.729402  2.699586  2.719088  2.672728
# 117_at      2.449451  2.368030  2.373510  2.382451  2.219530  2.378358
# 121_at      2.494397  2.600061  2.490088  2.492621  2.596983  2.522200
# 1255_g_at   1.558547  1.579119  1.454493  1.459492  1.406986  1.543821
#
#             Control9  Control10
# Unnamed: 0
# 1007_s_at   2.808096   2.862974
# 1053_at     2.668028   2.682455
# 117_at      2.535174   2.228848
# 121_at      2.670574   2.563204
# 1255_g_at   1.577974   1.573189
#
# [5 rows x 26 columns]

# %%
plt.figure(figsize=(15,15))
g= sns.clustermap(df.head(4675), yticklabels=False , cmap="RdYlGn")
ax = g.ax_heatmap
ax.set_ylabel("")
#plt.savefig("heatmap.png", bbox_inches = 'tight')
# Out:
# Text(651.9999999999999, 0.5, '')
